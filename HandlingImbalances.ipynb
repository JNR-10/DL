# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("customer_churn.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2481  6614-YWYSC    Male              1     Yes         No      61
# 3852  7291-CDTMJ    Male              0      No         No       1
# 1642  1498-DQNRX  Female              0     Yes         No      29
# 2737  5074-FBGHB    Male              0      No         No      64
# 427   8734-DKSTZ  Female              0     Yes        Yes      10
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 2481          Yes           Yes              No  No internet service  ...
# 3852          Yes            No              No  No internet service  ...
# 1642          Yes            No              No  No internet service  ...
# 2737          Yes           Yes     Fiber optic                   No  ...
# 427           Yes           Yes     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df.Churn.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
517400/df.shape[0]
# Out:
# 73.46301292063042

# %%
df.drop('customerID',axis='columns',inplace=True)

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Name: TotalCharges, Length: 7043, dtype: bool

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
df1 = df[df.TotalCharges!=' ']
df1.shape
# Out:
# (7032, 20)

# %%
df1.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df1.TotalCharges = pd.to_numeric(df1.TotalCharges)

# %%
df1.TotalCharges.values
# Out:
# array([  29.85, 1889.5 ,  108.15, ...,  346.45,  306.6 , 6844.5 ])

# %%
def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
df1.replace('No internet service','No',inplace=True)
df1.replace('No phone service','No',inplace=True)

# %%
print_unique_col_values(df1)
# Out:
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df1[col].replace({'Yes': 1,'No': 0},inplace=True)

# %%
for col in df1:
    print(f'{col}: {df1[col].unique()}')
# Out:
# gender: ['Female' 'Male']
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: [1 0]
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]

# %%
df1['gender'].replace({'Female':1,'Male':0},inplace=True)

# %%
df1.gender.unique()
# Out:
# array([1, 0])

# %%
df2 = pd.get_dummies(data=df1, columns=['InternetService','Contract','PaymentMethod'])
df2.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check'],
#       dtype='object')

# %%
df2.dtypes
# Out:
# gender                                       int64
# SeniorCitizen                                int64
# Partner                                      int64
# Dependents                                   int64
# tenure                                       int64
# PhoneService                                 int64
# MultipleLines                                int64
# OnlineSecurity                               int64
# OnlineBackup                                 int64
# DeviceProtection                             int64
# TechSupport                                  int64
# StreamingTV                                  int64
# StreamingMovies                              int64
# PaperlessBilling                             int64
# MonthlyCharges                             float64
# TotalCharges                               float64
# Churn                                        int64
# InternetService_DSL                          uint8
# ...

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2[cols_to_scale] = scaler.fit_transform(df2[cols_to_scale])

# %%
for col in df2:
    print(f'{col}: {df2[col].unique()}')
# Out:
# gender: [1 0]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# ...

# %%
X = df2.drop('Churn',axis='columns')
y = testLabels = df2.Churn.astype(np.float32)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
y_train.value_counts()
# Out:
# 0.0    4130
# 1.0    1495
# Name: Churn, dtype: int64

# %%
y.value_counts()
# Out:
# 0.0    5163
# 1.0    1869
# Name: Churn, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0.0    1033
# 1.0     374
# Name: Churn, dtype: int64

# %%
from tensorflow_addons import losses
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 from tensorflow_addons import losses
#
# ModuleNotFoundError: No module named 'tensorflow_addons'

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import confusion_matrix , classification_report
# Out:
# 2023-05-30 23:30:47.862607: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def ANN(X_train, y_train, X_test, y_test, loss, weights):
    model = keras.Sequential([
        keras.layers.Dense(26, input_dim=26, activation='relu'),
        keras.layers.Dense(15, activation='relu'),
        keras.layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
    
    if weights == -1:
        model.fit(X_train, y_train, epochs=100)
    else:
        model.fit(X_train, y_train, epochs=100, class_weight = weights)
    
    print(model.evaluate(X_test, y_test))
    
    y_preds = model.predict(X_test)
    y_preds = np.round(y_preds)
    
    print("Classification Report: \n", classification_report(y_test, y_preds))
    
    return y_preds

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 2ms/step - loss: 0.4967 - accuracy: 0.7504
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4320 - accuracy: 0.7899
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4221 - accuracy: 0.7954
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4177 - accuracy: 0.8012
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4160 - accuracy: 0.8016
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4130 - accuracy: 0.8021
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4114 - accuracy: 0.8011
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4094 - accuracy: 0.8046
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4090 - accuracy: 0.8064
# Epoch 10/100
# ...

# %%
## Mitigating Skewdness of Data

# %%
"""Method 1 - Undersampling """

# Class count
count_class_0, count_class_1 = df1.Churn.value_counts()

# Divide by class
df_class_0 = df2[df2['Churn'] == 0]
df_class_1 = df2[df2['Churn'] == 1]

# %%
df_class_0.shape
# Out:
# (5163, 27)

# %%
df_class_1.shape
# Out:
# (1869, 27)

# %%
# undersampling class_0

# Undersample 0-class and concat the DataFrames of both class
df_class_0_under = df_class_0.sample(count_class_1)
df_test_under = pd.concat([df_class_0_under, df_class_1], axis=0)

print('Random under-sampling: ')
print(df_test_under.Churn.value_counts())
# Out:
# Random under-sampling:
# 0    1869
# 1    1869
# Name: Churn, dtype: int64

# %%
X = df_test_under.drop('Churn',axis='columns')
y = df_test_under['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# stratify makes sure that you have balanced sample
# this ensures that samples in X_train and X_test have balanced sample having both possible outputs of y
# this prevents the situation when all the train or test sample have same possible output

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 0    1495
# 1    1495
# Name: Churn, dtype: int64

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 1s 2ms/step - loss: 0.6365 - accuracy: 0.6445
# Epoch 2/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5162 - accuracy: 0.7522
# Epoch 3/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4952 - accuracy: 0.7569
# Epoch 4/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4878 - accuracy: 0.7602
# Epoch 5/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4837 - accuracy: 0.7619
# Epoch 6/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4803 - accuracy: 0.7642
# Epoch 7/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4797 - accuracy: 0.7689
# Epoch 8/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4785 - accuracy: 0.7632
# Epoch 9/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4750 - accuracy: 0.7649
# Epoch 10/100
# ...

# %%
# check that the f1 score is now balanced for both 0 and 1 and not biased like previous

# %%
""" Method 2 - Oversampling """

# Oversample 1-class and concat the DataFrames of both classes
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over.Churn.value_counts())
# Out:
# Random over-sampling:
# 0    5163
# 1    5163
# Name: Churn, dtype: int64

# %%
X = df_test_over.drop('Churn',axis='columns')
y = df_test_over['Churn']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 1    4130
# 0    4130
# Name: Churn, dtype: int64

# %%
loss = keras.losses.BinaryCrossentropy()
weights = -1
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 259/259 [==============================] - 2s 2ms/step - loss: 0.5642 - accuracy: 0.7248
# Epoch 2/100
# 259/259 [==============================] - 1s 2ms/step - loss: 0.4982 - accuracy: 0.7577
# Epoch 3/100
# 259/259 [==============================] - 1s 2ms/step - loss: 0.4872 - accuracy: 0.7625
# Epoch 4/100
# 259/259 [==============================] - 1s 2ms/step - loss: 0.4816 - accuracy: 0.7660
# Epoch 5/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4768 - accuracy: 0.7685
# Epoch 6/100
# 259/259 [==============================] - 1s 2ms/step - loss: 0.4729 - accuracy: 0.7720
# Epoch 7/100
# 259/259 [==============================] - 1s 2ms/step - loss: 0.4694 - accuracy: 0.7726
# Epoch 8/100
# 259/259 [==============================] - 1s 2ms/step - loss: 0.4655 - accuracy: 0.7743
# Epoch 9/100
# 259/259 [==============================] - 1s 2ms/step - loss: 0.4628 - accuracy: 0.7753
# Epoch 10/100
# ...

# %%
# Individual F-1 scores have imporoved

# %%
""" Method 3 - SMOTE """

X = df2.drop('Churn',axis='columns')
y = df2['Churn']

# %%
from imblearn.over_sampling import SMOTE

# deprecated method usage
# smote = SMOTE(sampling_strategy='minority')
# X_sm, y_sm = smote.fit_sample(X, y)

smote = SMOTE(sampling_strategy='minority')
X_sm, y_sm = smote.fit_resample(X, y)

y_sm.value_counts()
# Out:
# 0    5163
# 1    5163
# Name: Churn, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.2, random_state=15, stratify=y_sm)

# %%
# Number of classes in training Data
y_train.value_counts()
# Out:
# 1    4130
# 0    4130
# Name: Churn, dtype: int64

# %%
y_preds = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 259/259 [==============================] - 2s 3ms/step - loss: 0.5120 - accuracy: 0.7504
# Epoch 2/100
# 259/259 [==============================] - 1s 5ms/step - loss: 0.4640 - accuracy: 0.7787
# Epoch 3/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4547 - accuracy: 0.7851
# Epoch 4/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4485 - accuracy: 0.7862
# Epoch 5/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4424 - accuracy: 0.7908
# Epoch 6/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4381 - accuracy: 0.7953
# Epoch 7/100
# 259/259 [==============================] - 1s 3ms/step - loss: 0.4345 - accuracy: 0.7987
# Epoch 8/100
# 259/259 [==============================] - 1s 2ms/step - loss: 0.4290 - accuracy: 0.8019
# Epoch 9/100
# 259/259 [==============================] - 1s 2ms/step - loss: 0.4271 - accuracy: 0.8019
# Epoch 10/100
# ...

# %%
""" Method 4 - Use of Ensamble with Undersampling """

df2.Churn.value_counts()
# Out:
# 0    5163
# 1    1869
# Name: Churn, dtype: int64

# %%
# Regain Original features and labels
X = df2.drop('Churn',axis='columns')
y = df2['Churn']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15, stratify=y)

# %%
y_train.value_counts()
# Out:
# 0    4130
# 1    1495
# Name: Churn, dtype: int64

# %%
# model1 --> class1(1495) + class0(0, 1495)

# model2 --> class1(1495) + class0(1496, 2990)

# model3 --> class1(1495) + class0(2990, 4130)

# %%
df3 = X_train.copy()
df3['Churn'] = y_train

# %%
df3_class0 = df3[df3.Churn==0]
df3_class1 = df3[df3.Churn==1]

# %%
def get_train_batch(df_majority, df_minority, start, end):
    df_train = pd.concat([df_majority[start:end], df_minority], axis=0)

    X_train = df_train.drop('Churn', axis='columns')
    y_train = df_train.Churn
    return X_train, y_train

# %%
X_train, y_train = get_train_batch(df3_class0, df3_class1, 0, 1495)

y_pred1 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 1s 3ms/step - loss: 0.6373 - accuracy: 0.6575
# Epoch 2/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.5260 - accuracy: 0.7438
# Epoch 3/100
# 94/94 [==============================] - 0s 4ms/step - loss: 0.4962 - accuracy: 0.7602
# Epoch 4/100
# 94/94 [==============================] - 1s 7ms/step - loss: 0.4884 - accuracy: 0.7656
# Epoch 5/100
# 94/94 [==============================] - 1s 6ms/step - loss: 0.4837 - accuracy: 0.7696
# Epoch 6/100
# 94/94 [==============================] - 1s 5ms/step - loss: 0.4808 - accuracy: 0.7702
# Epoch 7/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4780 - accuracy: 0.7702
# Epoch 8/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4768 - accuracy: 0.7699
# Epoch 9/100
# 94/94 [==============================] - 0s 4ms/step - loss: 0.4752 - accuracy: 0.7719
# Epoch 10/100
# ...

# %%
X_train, y_train = get_train_batch(df3_class0, df3_class1, 1495, 2990)

y_pred2 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 2s 3ms/step - loss: 0.6026 - accuracy: 0.6960
# Epoch 2/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5109 - accuracy: 0.7518
# Epoch 3/100
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4961 - accuracy: 0.7579
# Epoch 4/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4898 - accuracy: 0.7625
# Epoch 5/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4833 - accuracy: 0.7619
# Epoch 6/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4814 - accuracy: 0.7625
# Epoch 7/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4778 - accuracy: 0.7632
# Epoch 8/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4764 - accuracy: 0.7599
# Epoch 9/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.4726 - accuracy: 0.7686
# Epoch 10/100
# ...

# %%
X_train, y_train = get_train_batch(df3_class0, df3_class1, 2990, 4130)

y_pred3 = ANN(X_train, y_train, X_test, y_test, 'binary_crossentropy', -1)
# Out:
# Epoch 1/100
# 83/83 [==============================] - 1s 2ms/step - loss: 0.6125 - accuracy: 0.7176
# Epoch 2/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.5061 - accuracy: 0.7636
# Epoch 3/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4894 - accuracy: 0.7662
# Epoch 4/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4831 - accuracy: 0.7708
# Epoch 5/100
# 83/83 [==============================] - 0s 2ms/step - loss: 0.4784 - accuracy: 0.7761
# Epoch 6/100
# 83/83 [==============================] - 0s 2ms/step - loss: 0.4760 - accuracy: 0.7791
# Epoch 7/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4739 - accuracy: 0.7761
# Epoch 8/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4741 - accuracy: 0.7761
# Epoch 9/100
# 83/83 [==============================] - 0s 3ms/step - loss: 0.4698 - accuracy: 0.7780
# Epoch 10/100
# ...

# %%
# Majiority vote

"""
vote1 = 0
vote2 = 1
vote3 = 1
final = vote1+vote2+vote3
"""

# this shows that if the total of the votes is more than 1 than the majiority is 1, so using this logic

y_pred_final = y_pred1.copy()
for i in range(len(y_pred1)):
    n_ones = y_pred1[i] + y_pred2[i] + y_pred3[i]
    if n_ones>1:
        y_pred_final[i] = 1
    else:
        y_pred_final[i] = 0

# %%
cl_rep = classification_report(y_test, y_pred_final)
print(cl_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.65      0.76      1033
#            1       0.46      0.83      0.59       374
#
#     accuracy                           0.69      1407
#    macro avg       0.68      0.74      0.67      1407
# weighted avg       0.79      0.69      0.71      1407

# %%
# Not that good but atleast there is some balance in f1 scores as compared ot the normal original solution
